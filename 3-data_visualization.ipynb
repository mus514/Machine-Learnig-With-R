# %%
library(tidyverse)
library(palmerpenguins)
library(ggthemes)

# %%
head(penguins, 5)
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007

# %%
dplyr::glimpse
# Out:
# function (x, width = NULL, ...)
# {
#     UseMethod("glimpse")
# }
# <bytecode: 0x000001553dd9d488>
# <environment: namespace:pillar>

# %%
dplyr::glimpse(penguins)
# Out:
# Rows: 344
# Columns: 8
# $ species           <fct> Adelie, Adelie, Adelie, Adelie, Adelie, Adelie, Adel…
# $ island            <fct> Torgersen, Torgersen, Torgersen, Torgersen, Torgerse…
# $ bill_length_mm    <dbl> 39.1, 39.5, 40.3, NA, 36.7, 39.3, 38.9, 39.2, 34.1, …
# $ bill_depth_mm     <dbl> 18.7, 17.4, 18.0, NA, 19.3, 20.6, 17.8, 19.6, 18.1, …
# $ flipper_length_mm <int> 181, 186, 195, NA, 193, 190, 181, 195, 193, 190, 186…
# $ body_mass_g       <int> 3750, 3800, 3250, NA, 3450, 3650, 3625, 4675, 3475, …
# $ sex               <fct> male, female, female, NA, female, male, female, male…
# $ year              <int> 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007…

# %%
ggplot(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g)) +
    geom_point()
# Out:
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`)."
# plot without title

# %%
ggplot(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g, color = species)
) +
geom_point()
# Out:
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`)."
# plot without title

# %%
ggplot(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g, color = species)
) +
geom_point() +
geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`)."
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`)."
# plot without title

# %%
ggplot(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
geom_point(mapping = aes(color = species, shape = species)) +
geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`)."
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`)."
# plot without title

# %%
ggplot(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
geom_point(mapping = aes(color = species, shape = species))+ 
geom_smooth(method = 'lm') +
labs(
    title = "Body mass and flipper length",
    subtitle = 'test',
    x = "Flipper length (mm)", y = "Body mass (g)",
    color = "Species", shape = "Species"
) +
scale_color_colorblind()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`)."
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`)."
# plot without title

# %%
# Dimension
dim(penguins)
# Out:
# [1] 344   8

# %%
ggplot(
    data = penguins,
    mapping = aes(x = species, y = bill_length_mm)
) +
geom_boxplot()
# Out:
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range
# (`stat_boxplot()`)."
# plot without title

# %%
dplyr::glimpse(penguins)
# Out:
# Rows: 344
# Columns: 8
# $ species           <fct> Adelie, Adelie, Adelie, Adelie, Adelie, Adelie, Adel…
# $ island            <fct> Torgersen, Torgersen, Torgersen, Torgersen, Torgerse…
# $ bill_length_mm    <dbl> 39.1, 39.5, 40.3, NA, 36.7, 39.3, 38.9, 39.2, 34.1, …
# $ bill_depth_mm     <dbl> 18.7, 17.4, 18.0, NA, 19.3, 20.6, 17.8, 19.6, 18.1, …
# $ flipper_length_mm <int> 181, 186, 195, NA, 193, 190, 181, 195, 193, 190, 186…
# $ body_mass_g       <int> 3750, 3800, 3250, NA, 3450, 3650, 3625, 4675, 3475, …
# $ sex               <fct> male, female, female, NA, female, male, female, male…
# $ year              <int> 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007…

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
  geom_point(na.rm = TRUE, mapping = aes(color = bill_depth_mm)) +
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`)."
# plot without title

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g, color = island)
) +
  geom_point() +
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`)."
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`)."
# plot without title

# %%
penguins |>
ggplot(aes(x = flipper_length_mm, y = body_mass_g)) +
geom_point(na.rm = TRUE)
# Out:
# plot without title

# %%
penguins |> ggplot(aes(x = fct_infreq(species))) + geom_bar()
# Out:
# plot without title

# %%
penguins |> ggplot(aes(x = body_mass_g)) + geom_histogram(binwidth = 200, na.rm = TRUE)
# Out:
# plot without title

# %%
penguins |> ggplot(aes(x = body_mass_g)) + geom_density(na.rm = TRUE, aes(color = species, fill = species), alpha = 0.5)
# Out:
# plot without title
